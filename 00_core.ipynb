# %%
# default_exp core

# %% [markdown]
# # module name here
#
# > API details.

# %%
#hide
from nbdev.showdoc import *

# %%
#export 
def my_print (x):
    print (f'the value of x is {x}')

# %%
import matplotlib.pyplot as plt

plt.plot([1,2,3,5,12]);
